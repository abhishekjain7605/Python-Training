# %%
import random

# %%
while True:
    secret = random.randint(1, 6)
    guess = int(input("Guess the number (1-6): "))
    if guess == secret:
        print("Congratulations! You guessed it right.")
        break
    else:
        print(f"Wrong guess. The correct number was {secret}. Try again!")
# Out:
# Wrong guess. The correct number was 2. Try again!
# Wrong guess. The correct number was 1. Try again!
# Wrong guess. The correct number was 4. Try again!
# Wrong guess. The correct number was 5. Try again!
# Wrong guess. The correct number was 3. Try again!
# Wrong guess. The correct number was 2. Try again!
# Wrong guess. The correct number was 6. Try again!
# Wrong guess. The correct number was 3. Try again!
# Wrong guess. The correct number was 5. Try again!
# Congratulations! You guessed it right.
