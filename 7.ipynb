# %%
import pandas as pd

# %%
df = pd.DataFrame([
    [22,33,44,55,66],
    [34,56,78,76,78]
                  ])

# %%
df
# Out:
#     0   1   2   3   4
# 0  22  33  44  55  66
# 1  34  56  78  76  78

# %%
df3 = pd.DataFrame({
    'English' : [34,43,45,56,66],
    'Science' : [43,34,56,65,67],
    'Maths' : [45,54,77,87,78]
})

# %%
df3
# Out:
#    English  Science  Maths
# 0       34       43     45
# 1       43       34     54
# 2       45       56     77
# 3       56       65     87
# 4       66       67     78

# %%
df3.index = ['abhi','aadarsh','aaditya','chandu chai wala','Somaya chandu ki ghar wali']

# %%
df3
# Out:
#                             English  Science  Maths
# abhi                             34       43     45
# aadarsh                          43       34     54
# aaditya                          45       56     77
# chandu chai wala                 56       65     87
# Somaya chandu ki ghar wali       66       67     78

# %%
# Transpose
df3.T
# Out:
#          abhi  aadarsh  aaditya  chandu chai wala  Somaya chandu ki ghar wali
# English    34       43       45                56                          66
# Science    43       34       56                65                          67
# Maths      45       54       77                87                          78
